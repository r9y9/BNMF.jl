# %% [markdown]
# # Gamma Process Non-negative Matrix Factorization (GaP-NMF)
#
# Julia translation of MATALB code for GaP-NMF as in:
#
# [Bayesian Nonparametric Matrix Factorization for Recorded Music](http://soundlab.cs.princeton.edu/publications/2010_icml_gapnmf.pdf)
# by Matthew D. Hoffman et al. in ICML 2010
#
# The original MATLAB code: http://www.cs.princeton.edu/~mdhoffma/code/gapnmfmatlab.tar

# %%
using PyPlot

# %%
# Bayesian NMF package
using BNMF

# %%
# First we read a speech file using scipy.io.wavfile
using PyCall
@pyimport scipy.io.wavfile as wavfile 
fs, x = wavfile.read("arayuru.wav")
# Out:
# (16000,Int16[38,63,57,63,56,59,56,59,57,58  …  -44,-46,-44,-44,-44,-46,-44,-43,-41,-46])

# %%
# Short-Time Fourier Transform
include("stft.jl")
# Out:
# istft (generic function with 1 method)

# %%
# Compute spectrogram
framelen = 2048
X = stft(x, framelen=framelen, hopsize=256, window=hanning(framelen))
X = abs(X[:,1:framelen/2])

figure(figsize=(16, 6), dpi=80, facecolor="w", edgecolor="k")
imshow(log(X)', origin="lower", aspect="auto")
colorbar()
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x112ab2d50>)
# PyObject <matplotlib.colorbar.Colorbar instance at 0x10e4e5950>

# %%
p = GaPNMF(X, K=100, a=0.1, b=0.1, alpha=1.0, smoothness=100)
typeof(p)
# Out:
# GaPNMF (constructor with 3 methods)

# %%
tic()
fit!(p, epochs=100, verbose=true)
toc()
# Out:
# #1 bound: -258211.8991498503,
#                     improvement: NaN,
#                     activek: 100
# #2 bound: -166884.02283151506,
#                     improvement: 0.3536935231065171,
#                     activek: 100
# #3 bound: -129895.26044336965,
#                     improvement: 0.2216435208149854,
#                     activek: 100
# #4 bound: -113966.90981248708,
#                     improvement: 0.1226245713393588,
#                     activek: 100
# #5 bound: -105837.80316907831,
#                     improvement: 0.07132865721097303,
#                     activek: 100
# #6 bound: -99928.40824881068,
#                     improvement: 0.05583444424698836,
#                     activek: 100
# #7 bound: -93244.34446881863,
#                     improvement: 0.06688852446593037,
#                     activek: 100
# #8 bound: -83376.95561262302,
#                     improvement: 0.10582292054715786,
#                     activek: 100
# #9 bound: -68265.01667919569,
#                     improvement: 0.1812483895866717,
#                     activek: 100
# #10 bound: -46767.71766873452,
#                     improvement: 0.3149094522526154,
#                     activek: 97
# #11 bound: -19545.3152572104,
#                     improvement: 0.5820767779250222,
#                     activek: 91
# #12 bound: 10024.996822957153,
#                     improvement: 1.5129104693902986,
#                     activek: 82
# #13 bound: 40024.73515701902,
#                     improvement: 2.9924935502585632,
#                     activek: 74
# #14 bound: 70426.27248226033,
#                     improvement: 0.759568731834816,
#                     activek: 65
# #15 bound: 100232.01373200747,
#                     improvement: 0.42321906582880564,
#                     activek: 55
# #16 bound: 127484.16041080977,
#                     improvement: 0.2718906431598487,
#                     activek: 47
# #17 bound: 152216.02704177698,
#                     improvement: 0.19399952551964347,
#                     activek: 42
# #18 bound: 172006.63155433326,
#                     improvement: 0.13001656196902697,
#                     activek: 38
# #19 bound: 188441.6390530273,
#                     improvement: 0.09554868524649039,
#                     activek: 34
# #20 bound: 201392.0509932451,
#                     improvement: 0.06872372796849624,
#                     activek: 32
# #21 bound: 213399.64614672711,
#                     improvement: 0.0596229845927969,
#                     activek: 28
# #22 bound: 222194.74054711693,
#                     improvement: 0.04121419392768148,
#                     activek: 24
# #23 bound: 228846.78181073608,
#                     improvement: 0.02993788803119111,
#                     activek: 22
# #24 bound: 234046.9153647162,
#                     improvement: 0.022723210319299164,
#                     activek: 20
# #25 bound: 239187.29474039198,
#                     improvement: 0.02196302979539597,
#                     activek: 20
# #26 bound: 245096.2930634192,
#                     improvement: 0.02470448244101218,
#                     activek: 20
# #27 bound: 251192.35544614523,
#                     improvement: 0.024872111717938787,
#                     activek: 19
# #28 bound: 256705.59997170488,
#                     improvement: 0.02194829741441584,
#                     activek: 15
# #29 bound: 259900.47012184814,
#                     improvement: 0.012445658180014004,
#                     activek: 15
# #30 bound: 263239.5644172243,
#                     improvement: 0.012847588516522226,
#                     activek: 15
# #31 bound: 266799.95536759356,
#                     improvement: 0.013525288108766818,
#                     activek: 14
# #32 bound: 269466.3128131582,
#                     improvement: 0.009993845170967033,
#                     activek: 13
# #33 bound: 271587.6959012618,
#                     improvement: 0.00787253540510101,
#                     activek: 13
# #34 bound: 273695.20433687133,
#                     improvement: 0.007759955503933144,
#                     activek: 13
# #35 bound: 275756.97478346556,
#                     improvement: 0.0075330894145172545,
#                     activek: 12
# #36 bound: 277132.81042451697,
#                     improvement: 0.004989304956408686,
#                     activek: 12
# #37 bound: 278502.6149490954,
#                     improvement: 0.004942772826069039,
#                     activek: 12
# #38 bound: 279890.31041685044,
#                     improvement: 0.004982701753118786,
#                     activek: 12
# #39 bound: 281321.02916826867,
#                     improvement: 0.005111712332189743,
#                     activek: 12
# #40 bound: 282817.2010576459,
#                     improvement: 0.005318379126511433,
#                     activek: 12
# #41 bound: 284363.97872553446,
#                     improvement: 0.005469178190379166,
#                     activek: 12
# #42 bound: 286057.3427439135,
#                     improvement: 0.005954917447590962,
#                     activek: 11
# #43 bound: 287143.22337474447,
#                     improvement: 0.00379602432300804,
#                     activek: 10
# #44 bound: 287788.1278581536,
#                     improvement: 0.0022459331473321303,
#                     activek: 10
# #45 bound: 288400.8040684631,
#                     improvement: 0.002128914124669778,
#                     activek: 10
# #46 bound: 288983.92472791846,
#                     improvement: 0.002021910657769663,
#                     activek: 10
# #47 bound: 289543.34122410143,
#                     improvement: 0.0019358048954095397,
#                     activek: 10
# #48 bound: 290074.52555862773,
#                     improvement: 0.0018345589723480357,
#                     activek: 10
# #49 bound: 290585.0489120406,
#                     improvement: 0.0017599730704710938,
#                     activek: 10
# #50 bound: 291068.92287761625,
#                     improvement: 0.0016651715819079125,
#                     activek: 10
# #51 bound: 291529.68338768074,
#                     improvement: 0.001582994520710889,
#                     activek: 10
# #52 bound: 291967.88378251105,
#                     improvement: 0.0015031072985030875,
#                     activek: 10
# #53 bound: 292384.03107416455,
#                     improvement: 0.0014253187243138345,
#                     activek: 10
# #54 bound: 292778.6923138509,
#                     improvement: 0.001349804359138397,
#                     activek: 10
# #55 bound: 293152.7854802366,
#                     improvement: 0.0012777335790018593,
#                     activek: 10
# #56 bound: 293507.2958590411,
#                     improvement: 0.0012093024401039624,
#                     activek: 10
# #57 bound: 293843.05694849906,
#                     improvement: 0.00114396164659296,
#                     activek: 10
# #58 bound: 294160.9934841126,
#                     improvement: 0.0010819943779351467,
#                     activek: 10
# #59 bound: 294462.51705800695,
#                     improvement: 0.0010250290846622048,
#                     activek: 10
# #60 bound: 294749.1360034873,
#                     improvement: 0.0009733630899577704,
#                     activek: 10
# #61 bound: 295022.0193221787,
#                     improvement: 0.0009258154998906238,
#                     activek: 10
# #62 bound: 295282.3391921697,
#                     improvement: 0.0008823743752725129,
#                     activek: 10
# #63 bound: 295531.25197228545,
#                     improvement: 0.0008429653490171578,
#                     activek: 10
# #64 bound: 295769.6718301132,
#                     improvement: 0.0008067500686869172,
#                     activek: 10
# #65 bound: 295998.4567600723,
#                     improvement: 0.0007735239672934247,
#                     activek: 10
# #66 bound: 296217.9200608665,
#                     improvement: 0.0007414339358264929,
#                     activek: 10
# #67 bound: 296427.3545511466,
#                     improvement: 0.0007070284277098263,
#                     activek: 10
# #68 bound: 296626.22714515525,
#                     improvement: 0.0006708982519840809,
#                     activek: 10
# #69 bound: 296814.9154333882,
#                     improvement: 0.0006361146485560649,
#                     activek: 10
# #70 bound: 296994.25529437105,
#                     improvement: 0.0006042144503452067,
#                     activek: 10
# #71 bound: 297165.2309664033,
#                     improvement: 0.0005756867985975389,
#                     activek: 10
# #72 bound: 297328.42464551155,
#                     improvement: 0.0005491681465476573,
#                     activek: 10
# #73 bound: 297484.03535793076,
#                     improvement: 0.000523363054187409,
#                     activek: 10
# #74 bound: 297632.5431774549,
#                     improvement: 0.0004992127370649241,
#                     activek: 10
# #75 bound: 297774.6998948564,
#                     improvement: 0.00047762491253103615,
#                     activek: 10
# #76 bound: 297911.60543006525,
#                     improvement: 0.0004597621465395115,
#                     activek: 10
# #77 bound: 298044.0805543836,
#                     improvement: 0.000444679300516293,
#                     activek: 10
# #78 bound: 298172.17755006824,
#                     improvement: 0.0004297921147985822,
#                     activek: 10
# #79 bound: 298295.80493496935,
#                     improvement: 0.0004146174398862073,
#                     activek: 10
# #80 bound: 298414.9909518549,
#                     improvement: 0.00039955646346265966,
#                     activek: 10
# #81 bound: 298529.74292550975,
#                     improvement: 0.00038453823411758705,
#                     activek: 10
# #82 bound: 298640.3870568364,
#                     improvement: 0.00037063017655245434,
#                     activek: 10
# #83 bound: 298747.58770578145,
#                     improvement: 0.00035896232924669913,
#                     activek: 10
# #84 bound: 298851.87257026724,
#                     improvement: 0.00034907349474062226,
#                     activek: 10
# #85 bound: 298953.6803128579,
#                     improvement: 0.00034066288999654606,
#                     activek: 10
# #86 bound: 299053.43495030986,
#                     improvement: 0.0003336792420403209,
#                     activek: 10
# #87 bound: 299151.20134857914,
#                     improvement: 0.00032691949612790883,
#                     activek: 10
# #88 bound: 299246.7147383129,
#                     improvement: 0.00031928131761851627,
#                     activek: 10
# #89 bound: 299339.64485238004,
#                     improvement: 0.00031054681468575417,
#                     activek: 10
# #90 bound: 299429.83988660766,
#                     improvement: 0.0003013133601869036,
#                     activek: 10
# #91 bound: 299517.4900251448,
#                     improvement: 0.0002927234592596357,
#                     activek: 10
# #92 bound: 299602.76281203266,
#                     improvement: 0.00028470052577119794,
#                     activek: 10
# #93 bound: 299685.5935606806,
#                     improvement: 0.0002764685741562541,
#                     activek: 10
# #94 bound: 299766.0537087442,
#                     improvement: 0.0002684818683061356,
#                     activek: 10
# #95 bound: 299847.3384419119,
#                     improvement: 0.00027116056725592474,
#                     activek: 10
# #96 bound: 299923.50575512135,
#                     improvement: 0.00025402030781807115,
#                     activek: 10
# #97 bound: 299997.82919067715,
#                     improvement: 0.0002478079714648213,
#                     activek: 10
# #98 bound: 300070.46678947745,
#                     improvement: 0.00024212708137341283,
#                     activek: 10
# #99 bound: 300141.58659569145,
#                     improvement: 0.00023701034951866462,
#                     activek: 10
# #100 bound: 300211.43291694927,
#                     improvement: 0.0002327112415511682,
#                     activek: 10
# iteration finished
# elapsed time: 52.998461103 seconds
# 52.998461103

# %%
# Get active K-components
good = goodk(p)

goodspec = p.Eh[good,:]
# Out:
# 10x1024 Array{Float64,2}:
#   0.289746     0.969321      3.94549     …  0.000190822  0.000705614
#   0.00123374   0.00295106    0.00785697     0.0946909    0.0653125
#   1.20391      4.81999      10.8288         0.305619     0.229048
#   1.51623      0.73142       0.00620405     0.0253633    0.000202121
#   0.00245686   0.00533083    0.0120062      0.132919     0.187747
#   0.0906329    0.745892      3.046       …  0.846745     0.90044
#  25.3977      70.4174      177.279          0.00120459   0.00118893
#   0.00192799   0.00641193    0.0169392      0.000684287  0.000654855
#   0.0247056    0.0565925     0.132092       0.00819524   0.00745206
#   1.42951      0.0313334     0.0777307      0.00374154   0.00357048

# %%
# Visualize K-active spectrum
figure(figsize=(16, 6), dpi=80, facecolor="w", edgecolor="k")

for k=1:size(goodspec,1)
    plot(goodspec[k,:][:], label=string("#", k))
end
legend()
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x112ab2d10>)
# PyObject <matplotlib.legend.Legend object at 0x10e7b7050>

# %%
# Reconstruction by goodk
Y = xbar(p, good)
figure(figsize=(16, 6), dpi=80, facecolor="w", edgecolor="k")
imshow(log(Y)', origin="lower", aspect="auto", interpolation="nearest")
colorbar()
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x112abea90>)
# PyObject <matplotlib.colorbar.Colorbar instance at 0x113d011b8>

# %%
# E[templates]
figure(figsize=(16, 12), dpi=80, facecolor="w", edgecolor="k")
for k=1:length(good)
    subplot(length(good), 1, k)
    plot(p.Eh[good[k],:][:])
    xlim(0,1024)
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1135f0510>)

# %%
# E[activations]
figure(figsize=(16, 12), dpi=80, facecolor="w", edgecolor="k")
for k=1:length(good)
    subplot(length(good), 1, k)
    plot(p.Ew[:,good[k]][:])
    xlim(0, 229)
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x113096810>)

# %%
# Only length(good) components are active
figure(figsize=(16, 6), dpi=80, facecolor="w", edgecolor="k")
bar(good, p.Et[good])
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x113021690>)
# (PyObject <matplotlib.patches.Rectangle object at 0x1135201d0>,PyObject <matplotlib.patches.Rectangle object at 0x113520810>,PyObject <matplotlib.patches.Rectangle object at 0x113520e90>,PyObject <matplotlib.patches.Rectangle object at 0x113524550>,PyObject <matplotlib.patches.Rectangle object at 0x113524bd0>,PyObject <matplotlib.patches.Rectangle object at 0x113527290>,PyObject <matplotlib.patches.Rectangle object at 0x113527910>,PyObject <matplotlib.patches.Rectangle object at 0x113527f90>,PyObject <matplotlib.patches.Rectangle object at 0x113ca9650>,PyObject <matplotlib.patches.Rectangle object at 0x113ca9cd0>)
